# %% [markdown]
# #**Building a Simple Autoencoder**

# %%
#Importing Required Libraries

import tensorflow as tf 
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import regularizers , optimizers
from tensorflow.keras import backend as K
from matplotlib.offsetbox import OffsetImage, AnnotationBbox, TextArea
print('Tensorflow Version:',tf.__version__)
# Out:
# 2021-11-22 08:04:17.028066: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2021-11-22 08:04:17.028169: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow Version: 2.4.1

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
##Normalize all values between 0 and 1 and we will flatten the 28x28 images into vectors of size 784
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
x = np.array(x_train).reshape(-1, 28, 28) / 255.0
x_t = np.array(x_test).reshape(-1, 28, 28) / 255.0
labeldict = {
    0: 'T-shirt/top',
    1: 'Trouser',
    2: 'Pullover',
    3: 'Dress',
    4: 'Coat',
    5: 'Sandal',
    6: 'Shirt',
    7: 'Sneaker',
    8: 'Bag',
    9: 'Ankle boot'
}
fig, ax = plt.subplots(1, 10, figsize=(20, 2))
for i in range(10):
    ax[i].imshow(x[i], cmap='gray')
    ax[i].set_title(labeldict[y_train[i]])

# %%
unique, counts = np.unique(y_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 6000,
#  1: 6000,
#  2: 6000,
#  3: 6000,
#  4: 6000,
#  5: 6000,
#  6: 6000,
#  7: 6000,
#  8: 6000,
#  9: 6000}

# %%
# this is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats
# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
encoded = Dense(encoding_dim, activation='relu')(encoded)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)
# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)

encoder = Model(input_img, encoded)

# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))

# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]

# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))
# Out:
# 2021-11-22 08:20:12.710859: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-11-22 08:20:12.713890: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2021-11-22 08:20:12.713922: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-22 08:20:12.713979: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (479ff5f6eb83): /proc/driver/nvidia/version does not exist
# 2021-11-22 08:20:12.714343: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-22 08:20:12.714767: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
autoencoder.compile(loss = 'binary_crossentropy', optimizer = tf.keras.optimizers.Adam(lr = 0.001))
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 32)                25120
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               25872
# =================================================================
# Total params: 52,048
# Trainable params: 52,048
# Non-trainable params: 0
# _________________________________________________________________

# %%
##Train the autoencoder for 50 epochs
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# 2021-11-22 08:20:17.138689: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-11-22 08:20:17.151674: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# Epoch 1/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.4942 - val_loss: 0.3382
# Epoch 2/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3280 - val_loss: 0.3148
# Epoch 3/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3108 - val_loss: 0.3062
# Epoch 4/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3025 - val_loss: 0.3022
# Epoch 5/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2995 - val_loss: 0.2995
# Epoch 6/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2974 - val_loss: 0.2973
# Epoch 7/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2947 - val_loss: 0.2957
# Epoch 8/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2929 - val_loss: 0.2943
# Epoch 9/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2918 - val_loss: 0.2932
# Epoch 10/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2911 - val_loss: 0.2924
# Epoch 11/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2896 - val_loss: 0.2919
# Epoch 12/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2896 - val_loss: 0.2908
# Epoch 13/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2882 - val_loss: 0.2903
# Epoch 14/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2873 - val_loss: 0.2897
# Epoch 15/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2878 - val_loss: 0.2892
# Epoch 16/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2874 - val_loss: 0.2889
# Epoch 17/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2868 - val_loss: 0.2884
# Epoch 18/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2852 - val_loss: 0.2880
# Epoch 19/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2854 - val_loss: 0.2876
# Epoch 20/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2851 - val_loss: 0.2875
# Epoch 21/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2851 - val_loss: 0.2871
# Epoch 22/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2842 - val_loss: 0.2870
# Epoch 23/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2847 - val_loss: 0.2867
# Epoch 24/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2842 - val_loss: 0.2867
# Epoch 25/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2840 - val_loss: 0.2869
# Epoch 26/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2843 - val_loss: 0.2861
# Epoch 27/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2845 - val_loss: 0.2861
# Epoch 28/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2846 - val_loss: 0.2859
# Epoch 29/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2838 - val_loss: 0.2857
# Epoch 30/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2837 - val_loss: 0.2857
# Epoch 31/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2837 - val_loss: 0.2856
# Epoch 32/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2834 - val_loss: 0.2854
# Epoch 33/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2830 - val_loss: 0.2855
# Epoch 34/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2830 - val_loss: 0.2852
# Epoch 35/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2835 - val_loss: 0.2851
# Epoch 36/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2826 - val_loss: 0.2850
# Epoch 37/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2826 - val_loss: 0.2850
# Epoch 38/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2825 - val_loss: 0.2849
# Epoch 39/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2829 - val_loss: 0.2851
# Epoch 40/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2824 - val_loss: 0.2848
# Epoch 41/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2824 - val_loss: 0.2848
# Epoch 42/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2822 - val_loss: 0.2847
# Epoch 43/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2825 - val_loss: 0.2846
# Epoch 44/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2830 - val_loss: 0.2846
# Epoch 45/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2823 - val_loss: 0.2846
# Epoch 46/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2820 - val_loss: 0.2845
# Epoch 47/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2821 - val_loss: 0.2844
# Epoch 48/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2815 - val_loss: 0.2844
# Epoch 49/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2827 - val_loss: 0.2844
# Epoch 50/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2819 - val_loss: 0.2844

# %% [markdown]
# ##**Data Visualization**

# %%
# encode and decode some digits
# note that we take them from the test set

encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
# use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# # now lets build a convolution encoder model

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

def make_and_fit():
    inputs = Input(shape=(28, 28, 1))
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = BatchNormalization()(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)
    x = BatchNormalization()(x)
    x = Conv2D(16, (2, 2), activation='relu', padding='same')(x)
    x = Conv2D(4, (2, 2), activation='relu', padding='same')(x)
    x = Conv2D(1, (2, 2), activation='relu', padding='same')(x)
    x = Flatten()(x)
    encoded = Dense(2, activation='relu')(x)
    
    encoder = Model(inputs=inputs, outputs=encoded)
    
    encoded_inputs = Input(shape=(2,))

    x = Dense(4, activation='relu')(encoded_inputs)
    x = Reshape((2, 2, 1))(x)
    x = Conv2D(4, (2, 2), activation='relu', padding='same')(x)
    x = Conv2D(16, (2, 2), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = UpSampling2D((7, 7))(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = UpSampling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

    decoder = Model(inputs=encoded_inputs, outputs=decoded)
    
    x = encoder(inputs)
    x = decoder(x)
    model = Model(inputs=inputs, outputs=x)
    model.compile(optimizer=optimizers.Adam(1e-3), loss='binary_crossentropy', metrics=['accuracy', 'mse'])

    print(model.summary())
    clr = ReduceLROnPlateau(monitor='loss',
        factor=0.5,patience=3,min_delta=0.01,
        min_lr=1e-7,verbose=1)
    model.fit(x_train,x_train,
        batch_size=256,epochs=20,shuffle=True,
        validation_data=(x_test, x_test),
        callbacks=[clr])

    return model, encoder, decoder

# %%
model , encoder , decoder = make_and_fit()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# model_3 (Functional)         (None, 2)                 30761
# _________________________________________________________________
# model_4 (Functional)         (None, 28, 28, 1)         33169
# =================================================================
# Total params: 63,930
# Trainable params: 63,706
# Non-trainable params: 224
# _________________________________________________________________
# None
# Epoch 1/20
# 235/235 [==============================] - 240s 1s/step - loss: 0.4585 - accuracy: 0.4813 - mse: 0.0750 - val_loss: 1.1184 - val_accuracy: 0.4999 - val_mse: 0.1941
# Epoch 2/20
# 235/235 [==============================] - 238s 1s/step - loss: 0.3947 - accuracy: 0.4929 - mse: 0.0521 - val_loss: 1.0479 - val_accuracy: 0.4998 - val_mse: 0.1709
# Epoch 3/20
# 235/235 [==============================] - 240s 1s/step - loss: 0.3863 - accuracy: 0.4965 - mse: 0.0491 - val_loss: 0.4077 - val_accuracy: 0.4971 - val_mse: 0.0555
# Epoch 4/20
# 235/235 [==============================] - 237s 1s/step - loss: 0.3838 - accuracy: 0.4953 - mse: 0.0480 - val_loss: 0.3955 - val_accuracy: 0.4878 - val_mse: 0.0519
# Epoch 5/20
# 235/235 [==============================] - 236s 1s/step - loss: 0.3823 - accuracy: 0.4956 - mse: 0.0475 - val_loss: 0.3849 - val_accuracy: 0.4948 - val_mse: 0.0480
# Epoch 6/20
# 235/235 [==============================] - 235s 1000ms/step - loss: 0.3799 - accuracy: 0.4966 - mse: 0.0469 - val_loss: 0.3819 - val_accuracy: 0.4943 - val_mse: 0.0471
# Epoch 7/20
# 235/235 [==============================] - 243s 1s/step - loss: 0.3790 - accuracy: 0.4971 - mse: 0.0467 - val_loss: 0.3852 - val_accuracy: 0.4957 - val_mse: 0.0485
# Epoch 8/20
# 235/235 [==============================] - 238s 1s/step - loss: 0.3773 - accuracy: 0.4967 - mse: 0.0461 - val_loss: 0.3819 - val_accuracy: 0.4924 - val_mse: 0.0471
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/20
# 235/235 [==============================] - 243s 1s/step - loss: 0.3763 - accuracy: 0.4965 - mse: 0.0458 - val_loss: 0.3798 - val_accuracy: 0.4915 - val_mse: 0.0464
# Epoch 10/20
# 235/235 [==============================] - 237s 1s/step - loss: 0.3756 - accuracy: 0.4970 - mse: 0.0455 - val_loss: 0.3809 - val_accuracy: 0.4917 - val_mse: 0.0467
# Epoch 11/20
# 235/235 [==============================] - 239s 1s/step - loss: 0.3762 - accuracy: 0.4960 - mse: 0.0456 - val_loss: 0.3808 - val_accuracy: 0.4925 - val_mse: 0.0467
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 12/20
# 235/235 [==============================] - 244s 1s/step - loss: 0.3749 - accuracy: 0.4960 - mse: 0.0451 - val_loss: 0.3761 - val_accuracy: 0.4936 - val_mse: 0.0450
# Epoch 13/20
# 235/235 [==============================] - 237s 1s/step - loss: 0.3739 - accuracy: 0.4973 - mse: 0.0450 - val_loss: 0.3776 - val_accuracy: 0.4944 - val_mse: 0.0456
# Epoch 14/20
# 235/235 [==============================] - 240s 1s/step - loss: 0.3733 - accuracy: 0.4974 - mse: 0.0448 - val_loss: 0.3754 - val_accuracy: 0.4960 - val_mse: 0.0448
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 15/20
# 235/235 [==============================] - 239s 1s/step - loss: 0.3721 - accuracy: 0.4984 - mse: 0.0445 - val_loss: 0.3745 - val_accuracy: 0.4953 - val_mse: 0.0445
# Epoch 16/20
# 235/235 [==============================] - 238s 1s/step - loss: 0.3728 - accuracy: 0.4965 - mse: 0.0444 - val_loss: 0.3750 - val_accuracy: 0.4940 - val_mse: 0.0447
# Epoch 17/20
# 235/235 [==============================] - 237s 1s/step - loss: 0.3731 - accuracy: 0.4967 - mse: 0.0446 - val_loss: 0.3758 - val_accuracy: 0.4935 - val_mse: 0.0450
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 18/20
# 235/235 [==============================] - 239s 1s/step - loss: 0.3734 - accuracy: 0.4957 - mse: 0.0446 - val_loss: 0.3746 - val_accuracy: 0.4950 - val_mse: 0.0445
# Epoch 19/20
# 235/235 [==============================] - 237s 1s/step - loss: 0.3718 - accuracy: 0.4978 - mse: 0.0444 - val_loss: 0.3741 - val_accuracy: 0.4952 - val_mse: 0.0444
# Epoch 20/20
# 235/235 [==============================] - 237s 1s/step - loss: 0.3722 - accuracy: 0.4980 - mse: 0.0445 - val_loss: 0.3742 - val_accuracy: 0.4955 - val_mse: 0.0444
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
# use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
